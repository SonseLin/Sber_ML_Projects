# %% [markdown]
# # 5 примеров ML аппликейшинов
# ### Здравоохранение
# для анализа мединиской даты(снимки, записи болезней)
#
# ### Финансы
# стоит ли давать кредит человеку
#
# ### Сфера продаж
# предиктор цены на товар
#
# предиктор стоимости квартир
#
# ### Карты
# предиктор путей с учетом пробок и транспорта

# %% [markdown]
# # Multiclass VS Multilabel
# В мультиклассе каждый объект принадлежит конкретно к одному классу из многих
# В мультилейбле каждый объект может принадлежать к 2 и более классам, не ограничиваясь одним(т е как система тегов у чего-либо)

# %% [markdown]
# # House problem
# Предсказание стоимости домов это задача регрессии, ибо мы стараемся определить количественную величину(стоимость дома)
#
# ### Можно ли переквалифицировать проблему до классификации?
# Думаю можно, если поставим задачу как "определи к какой категории приходится недвижимость(элитный класс, бюджет, средний)"
